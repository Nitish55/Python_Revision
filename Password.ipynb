# %%
pwd=input("Enetr a pssword of length 5:- ")
sp_c="!@#$%^&*"
lt=[]
lt_c=[]
flag=0
flag1=0
flag2=0   
lt_d=[]

# for Length
while len(pwd)<5:
    print("Invalid Password, Pwd length shour be more than 5")
    pwd=input("Re-Enter Password:- ")
    continue

#----------------------------------------------------------------------------------------------------------------------------- 

# For special char    
for i in pwd:
    if i in sp_c:
        flg=1
        lt.append(flg)
    else:
        flg=0
        lt.append(flg)
for i in lt:
    flag=i+flag

while flag==0:
    print("Invalid Password, Passwrd contain at least on special char-[! @ # $ % ^ &]")
    pwd=input("Re-Enter Password:- ")
    for i in pwd:
        if i in sp_c:
            flg=1
            lt.append(flg)
        else:
            flg=0
            lt.append(flg)
    for i in lt:
        flag=i+flag
        continue
#-----------------------------------------------------------------------------------------------------------------------------        
# For Caps
for j in pwd:
    if j.isupper()==True:
        flg1=1
        lt_c.append(flg1)
    else:
        flg1=0
        lt_c.append(flg1)
for i in lt_c:
    flag1=i+flag1

while flag1==0:
    print("Invalid Password, Passwrd contain at least character one in Caps")
    pwd=input("Re-Enter Password:- ")
    for j in pwd:
        if j.isupper()==True:
            flg1=1
            lt_c.append(flg1)
        else:
            flg1=0
            lt_c.append(flg1)
    for i in lt_c:
        flag1=i+flag1
    continue
#-----------------------------------------------------------------------------------------------------------------------------     
# For Numeric
for k in pwd:
    if k.isdigit()==True:
        flg2=1
        lt_d.append(flg2)
    else:
        flg2=0
        lt_d.append(flg2)
for i in lt_d:
    flag2=i+flag2
flag2

while flag2==0:
    print("Invalid Password, Passwrd contain at least one Numeric value")
    pwd=input("Re-Enter Password:- ")
    for k in pwd:
        if k.isdigit()==True:
            flg2=1
            lt_d.append(flg2)
        else:
            flg2=0
            lt_d.append(flg2)
    for i in lt_d:
        flag2=i+flag2
    continue
print("Enterd Password is",pwd)
# Out:
# Enetr a pssword of length 5:- Honey5@
# Enterd Password is Honey5@
