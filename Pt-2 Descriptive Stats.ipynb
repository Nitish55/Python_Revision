# %% [markdown]
# ### Limiting the number of rows

# %%
import pandas as pd
pd.options.display.max_rows=100

# %% [markdown]
# ### This will set the rows to 10 rows globally

# %%
dta=pd.read_csv("covid.csv",encoding='cp1252')
dta
# Out:
#                                              description  \
# 0       Business status Alert Level 4: Fully operational
# 1       Business status Alert Level 4: Fully operational
# 2       Business status Alert Level 4: Fully operational
# 3       Business status Alert Level 4: Fully operational
# 4       Business status Alert Level 4: Fully operational
# ...                                                  ...
# 10053  Reasons why you expect COVID-19 pandemic to ch...
# 10054  Reasons why you expect COVID-19 pandemic to ch...
# 10055  Reasons why you expect COVID-19 pandemic to ch...
# 10056  Reasons why you expect COVID-19 pandemic to ch...
# 10057  Reasons why you expect COVID-19 pandemic to ch...
#
#                                industry  level             size line_code  \
# 0                                 total      0   6–19 employees  C0301.01
# 1                                 total      0  20–49 employees  C0301.01
# ...

# %% [markdown]
# ## In case we want to display them locally (nrows)

# %%
rw=pd.read_csv("covid.csv",encoding='cp1252',nrows=5)
rw
# Out:
#                                         description  \
# 0  Business status Alert Level 4: Fully operational
# 1  Business status Alert Level 4: Fully operational
# 2  Business status Alert Level 4: Fully operational
# 3  Business status Alert Level 4: Fully operational
# 4  Business status Alert Level 4: Fully operational
#
#                            industry  level             size line_code  value
# 0                             total      0   6–19 employees  C0301.01   6054
# 1                             total      0  20–49 employees  C0301.01   1650
# 2                             total      0  50–99 employees  C0301.01    735
# 3                             total      0   100+ employees  C0301.01    711
# 4  Agriculture, forestry, & fishing      1            total  C0301.01   2175

# %% [markdown]
# # ChunkSize

# %% [markdown]
# #### Chunksize- Basically it perform an extraction operation i.e if we give chucksize=100 then it will extract 10 bytes of data in a text format...this will extracte data upto only  100byte from the data.

# %%
import pandas as pd

# %%
chck=pd.read_csv("covid.csv",encoding='cp1252',chunksize=10)
chck

# %%
for chunk in chck:
    print (chunk)
# Out:
#                                         description  \
# 0  Business status Alert Level 4: Fully operational
# 1  Business status Alert Level 4: Fully operational
# 2  Business status Alert Level 4: Fully operational
# 3  Business status Alert Level 4: Fully operational
# 4  Business status Alert Level 4: Fully operational
# 5  Business status Alert Level 4: Fully operational
# 6  Business status Alert Level 4: Fully operational
# 7  Business status Alert Level 4: Fully operational
# 8  Business status Alert Level 4: Fully operational
# 9  Business status Alert Level 4: Fully operational
#
#                                             industry  level             size  \
# 0                                              total      0   6–19 employees
# 1                                              total      0  20–49 employees
# 2                                              total      0  50–99 employees
# 3                                              total      0   100+ employees
# ...

# %%
df=chunk
df
# Out:
#                                              description  \
# 10050  Reasons why you expect COVID-19 pandemic to ch...
# 10051  Reasons why you expect COVID-19 pandemic to ch...
# 10052  Reasons why you expect COVID-19 pandemic to ch...
# 10053  Reasons why you expect COVID-19 pandemic to ch...
# 10054  Reasons why you expect COVID-19 pandemic to ch...
# 10055  Reasons why you expect COVID-19 pandemic to ch...
# 10056  Reasons why you expect COVID-19 pandemic to ch...
# 10057  Reasons why you expect COVID-19 pandemic to ch...
#
#                                 industry  level   size line_code  value
# 10050            Computer systems design      2  total     C2309     12
# 10051      Other professional scientific      2  total     C2309      0
# 10052  Administrative & support services      1  total     C2309     12
# 10053               Education & training      1  total     C2309     21
# 10054    Health care & social assistance      1  total     C2309     27
# ...

# %%
df.columns
# Out:
# Index(['description', 'industry', 'level', 'size', 'line_code', 'value'], dtype='object')

# %%
df.shape
# Out:
# (58, 6)

# %% [markdown]
# ## Writing data back to Hard-Drive in CSV format

# %%
 gt=pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv",
                sep="\t")
gt
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
gt.to_csv("titanic.csv")

# %% [markdown]
# #### We can store the data in any format like to_josn,to_dict,to_clipboard etc, Simply put cursor on gt.to_csv() after underscore and press "TAB" not shift+ tab

# %% [markdown]
# ### Putting separator in the data:-

# %%
gt.to_csv("titanic_sep.csv",sep="#")

# %% [markdown]
# ### na_rep --> Basically it fills the null values with the values provided

# %%
fle=pd.read_csv("Null_val.txt",sep=',')
fle
# Out:
#     Name   age     sex  salary
# 0   John  33.0    Male     NaN
# 1    NaN  32.0  Female  3000.0
# 2    NaN   NaN    Male     NaN
# 3  Kumar  22.0    Male  5000.0

# %%
import sys
fle.to_csv(sys.stdout,na_rep="Random")
# Out:
# ,Name,age,sex,salary
# 0,John,33.0,Male,Random
# 1,Random,32.0,Female,3000.0
# 2,Random,Random,Male,Random
# 3,Kumar,22.0,Male,5000.0

# %% [markdown]
# ## But this is not a good approcah we use imputation to fill records

# %% [markdown]
# ### Suppose we want to skip both Index as well as Header

# %%
gt.to_csv("titanic_wout_header_index.csv",index=False,header=False)

# %% [markdown]
# ### Saving only selected coulmns

# %%
gt.to_csv("titanic_selct_cols.csv",index=False,columns=["Name","Sex","Age","SibSp"])

# %% [markdown]
# # Date-Part

# %%
pd.date_range("01-01-2000",periods=7)
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# ##### basically it generates data of 7days starting from 01-01-2000 to 07-01-2000 coz period is given 7

# %% [markdown]
# #### We can also provide freq- D-days-Y-year, m-Month

# %%
pd.date_range("01-01-2000",periods=3,freq="M")
# Out:
# DatetimeIndex(['2000-01-31', '2000-02-29', '2000-03-31'], dtype='datetime64[ns]', freq='M')

# %% [markdown]
# #### when we give freq as Y or D itvgives last day as the output

# %% [markdown]
# ### Specifying stop date

# %%
dt=pd.date_range(start="01-01-2000",end="01-01-2001")

# %%
dt
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10',
#                ...
#                '2000-12-23', '2000-12-24', '2000-12-25', '2000-12-26',
#                '2000-12-27', '2000-12-28', '2000-12-29', '2000-12-30',
#                '2000-12-31', '2001-01-01'],
#               dtype='datetime64[ns]', length=367, freq='D')

# %%
dt.shape 
# means it include all the days of the yr 200 to 2001
# Out:
# (367,)

# %%
pd.date_range(start="01-01-2000",end="01-01-2001",periods=4)
# Out:
# DatetimeIndex(['2000-01-01', '2000-05-02', '2000-09-01', '2001-01-01'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ### Creating your own Index

# %%
import numpy as np
ts=pd.Series(np.arange(3),index=["Nitish","John","Kumar"])
ts
# Out:
# Nitish    0
# John      1
# Kumar     2
# dtype: int32

# %% [markdown]
# ##### Similarly we can do with dates as well

# %%
dte=pd.date_range("01-01-2000",periods=6)
dte
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
t=pd.Series(np.arange(6),index=dte)
t
# Out:
# 2000-01-01    0
# 2000-01-02    1
# 2000-01-03    2
# 2000-01-04    3
# 2000-01-05    4
# 2000-01-06    5
# Freq: D, dtype: int32

# %% [markdown]
# #### Writing this dataset back into csv format

# %%
t.to_csv("timeseries.csv")

# %% [markdown]
#  # Working with files without using Pandas

# %%
import csv
f=open('Sample_fle.csv')
reader=csv.reader(f)
list(reader)
# Out:
# [['Key1', 'Key2', 'Value1', 'Value2'],
#  ['one', 'a', '1', '2'],
#  ['one', 'b', '3', '4'],
#  ['one', 'c', '5', '6'],
#  ['one', 'd', '7', '8'],
#  ['two', 'a', '9', '10'],
#  ['two', 'b', '11', '12'],
#  ['two', 'c', '13', '14'],
#  ['two', 'd', '15', '16']]

# %% [markdown]
# # OR we can Do-

# %%
with open('Sample_fle.csv') as f:
    lines=list(csv.reader(f))
lines
# Out:
# [['Key1', 'Key2', 'Value1', 'Value2'],
#  ['one', 'a', '1', '2'],
#  ['one', 'b', '3', '4'],
#  ['one', 'c', '5', '6'],
#  ['one', 'd', '7', '8'],
#  ['two', 'a', '9', '10'],
#  ['two', 'b', '11', '12'],
#  ['two', 'c', '13', '14'],
#  ['two', 'd', '15', '16']]

# %%
lines[0]
# Out:
# ['Key1', 'Key2', 'Value1', 'Value2']

# %%
lines[3]
# Out:
# ['one', 'c', '5', '6']

# %% [markdown]
# ## We know that:-

# %%
a=1
b="nitish"
c=23

# %%
a,b,c=1,"nitish",23

# %%
b
# Out:
# 'nitish'

# %% [markdown]
# ## Similar operation we can do with files

# %%
header,values=lines[0],lines[1:]
header
# Out:
# ['Key1', 'Key2', 'Value1', 'Value2']

# %%
values
# Out:
# [['one', 'a', '1', '2'],
#  ['one', 'b', '3', '4'],
#  ['one', 'c', '5', '6'],
#  ['one', 'd', '7', '8'],
#  ['two', 'a', '9', '10'],
#  ['two', 'b', '11', '12'],
#  ['two', 'c', '13', '14'],
#  ['two', 'd', '15', '16']]

# %%
list(zip(values))
# Out:
# [(['one', 'a', '1', '2'],),
#  (['one', 'b', '3', '4'],),
#  (['one', 'c', '5', '6'],),
#  (['one', 'd', '7', '8'],),
#  (['two', 'a', '9', '10'],),
#  (['two', 'b', '11', '12'],),
#  (['two', 'c', '13', '14'],),
#  (['two', 'd', '15', '16'],)]

# %% [markdown]
# #### If we pass steric * of values it means we are suggesting our complier that we dont have single values we have multiple values

# %%
list(zip(*values))
# Out:
# [('one', 'one', 'one', 'one', 'two', 'two', 'two', 'two'),
#  ('a', 'b', 'c', 'd', 'a', 'b', 'c', 'd'),
#  ('1', '3', '5', '7', '9', '11', '13', '15'),
#  ('2', '4', '6', '8', '10', '12', '14', '16')]

# %%
list(zip(header,zip(*values)))
# Out:
# [('Key1', ('one', 'one', 'one', 'one', 'two', 'two', 'two', 'two')),
#  ('Key2', ('a', 'b', 'c', 'd', 'a', 'b', 'c', 'd')),
#  ('Value1', ('1', '3', '5', '7', '9', '11', '13', '15')),
#  ('Value2', ('2', '4', '6', '8', '10', '12', '14', '16'))]

# %% [markdown]
# #### Dict Comprehension

# %%
data_dict={h:v for h, v in zip(header,zip(*values))}
data_dict
# Out:
# {'Key1': ('one', 'one', 'one', 'one', 'two', 'two', 'two', 'two'),
#  'Key2': ('a', 'b', 'c', 'd', 'a', 'b', 'c', 'd'),
#  'Value1': ('1', '3', '5', '7', '9', '11', '13', '15'),
#  'Value2': ('2', '4', '6', '8', '10', '12', '14', '16')}

# %% [markdown]
# ### Assignment

# %%
l1=[1,2,3,4,5]
l2=[6,7,8,9,10]
zp=zip(l1,l2)
zn=list(zp)
zn
# Out:
# [(1, 6), (2, 7), (3, 8), (4, 9), (5, 10)]

# %%
#Write data in dictionary from Zip
l1=[1,2,3,4,5]
l2=[6,7,8,9,10]
s=lambda *args:{l1[i]:l2[i] for i in range(len(zn))}
s(a,b)
# Out:
# {1: 6, 2: 7, 3: 8, 4: 9, 5: 10}

# %%
l1=[1,2,3,4,5]
l2=[6,7,8,9,10]
{a:b for a,b in zip(l1,l2)}
# Out:
# {1: 6, 2: 7, 3: 8, 4: 9, 5: 10}

# %% [markdown]
# ## JSON(Java Script Object Notation)
# #### store data in form of dictionary

# %%
obj="""
{"name":"Wes",
 "Places_Lived": ["United_state","Spain","Germany"],
 "Pet":"null",
 "Siblings": [{"Name":"Scott","Age":30,"Pets":["Zeus","Zuko"]},
 {"Name":"Katie","Age":26,
 "Pets":["Tommy","Dollar","Cisco"]}]
}
"""
obj
# Out:
# '\n{"name":"Wes",\n "Places_Lived": ["United_state","Spain","Germany"],\n "Pet":"null",\n "Siblings": [{"Name":"Scott","Age":30,"Pets":["Zeus","Zuko"]},\n {"Name":"Katie","Age":26,\n "Pets":["Tommy","Dollar","Cisco"]}]\n}\n'

# %%
type(obj)
# Out:
# str

# %% [markdown]
# #### To convert json data into dictionary

# %%
import json
rslt=json.loads(obj)
rslt
# Out:
# {'name': 'Wes',
#  'Places_Lived': ['United_state', 'Spain', 'Germany'],
#  'Pet': 'null',
#  'Siblings': [{'Name': 'Scott', 'Age': 30, 'Pets': ['Zeus', 'Zuko']},
#   {'Name': 'Katie', 'Age': 26, 'Pets': ['Tommy', 'Dollar', 'Cisco']}]}

# %% [markdown]
# #### Json Viewer "http://jsonviewer.stack.hu/"

# %%
type(rslt)
# Out:
# dict

# %% [markdown]
# #### To convert json data back into string

# %%
asjson=json.dumps(rslt)
asjson
# Out:
# '{"name": "Wes", "Places_Lived": ["United_state", "Spain", "Germany"], "Pet": "null", "Siblings": [{"Name": "Scott", "Age": 30, "Pets": ["Zeus", "Zuko"]}, {"Name": "Katie", "Age": 26, "Pets": ["Tommy", "Dollar", "Cisco"]}]}'

# %%
type(asjson)
# Out:
# str

# %% [markdown]
# ##### In order to read in DataFrame

# %%
df=pd.DataFrame(rslt["Siblings"])
df
# Out:
#     Name  Age                    Pets
# 0  Scott   30            [Zeus, Zuko]
# 1  Katie   26  [Tommy, Dollar, Cisco]

# %%
# If we do
df=pd.DataFrame(rslt)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-3856bd3a264b> in <module>
#       1 # If we do
# ----> 2 df=pd.DataFrame(rslt)
#       3 df
#
# E:\Software_install\anaconda\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# E:\Software_install\anaconda\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
# ...

# %%
# Adding columns
df=pd.DataFrame(rslt["Places_Lived"],columns=["Place_Lives"])
df
# Out:
#     Place_Lives
# 0  United_state
# 1         Spain
# 2       Germany

# %%
df=pd.DataFrame(rslt["Siblings"],columns=["Name","umar","no_pts"])
df
# Out:
#     Name  umar  no_pts
# 0  Scott   NaN     NaN
# 1  Katie   NaN     NaN

# %%
df=pd.DataFrame(rslt["Siblings"],columns=["Name","Age","Pets"])
df
# Out:
#     Name  Age                    Pets
# 0  Scott   30            [Zeus, Zuko]
# 1  Katie   26  [Tommy, Dollar, Cisco]

# %% [markdown]
# ## Reading JSON file

# %%
dta=pd.read_json("exmple.json")
dta
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
dta.to_json()
# Out:
# '{"a":{"0":1,"1":4,"2":7},"b":{"0":2,"1":5,"2":8},"c":{"0":3,"1":6,"2":9}}'

# %% [markdown]
# #### Here data is store in key vaule pair, the value comprises of combination of index as well as value undera,b,c respectively

# %%
#If we do
print(dta.to_json(orient="records"))
# Out:
# [{"a":1,"b":2,"c":3},{"a":4,"b":5,"c":6},{"a":7,"b":8,"c":9}]

# %% [markdown]
# #### It will save records same as th eoriginal Json file

# %% [markdown]
# # Binary Data Format

# %%
pk=pd.read_csv("Sample_Pikle.csv")
pk.to_pickle("frame_pickle")

# %%
# To read using PAndas while we cant read it when we try to open in windows
pd.read_pickle("frame_pickle")
# Out:
#   Key1 Key2  Value1  Value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10
# 5  two    b      11      12
# 6  two    c      13      14
# 7  two    d      15      16

# %% [markdown]
# #### Pickle is a binary data file
# #### Whenervr binary file try to perform write or read operation, it perform a SERDE operation
# #### we have dataset in Object format which we want to convert into Object_Byte_Code while storing data into pickle file format
# #### --->This is called serialization/write in binary file format
# #### if we convert file into Object_Byte_Code to Object this is called deserialization/Read operation

# %% [markdown]
# ### Using HDF Format, Note:- there are many more formats, We need diff file frmat coz there metastructure is different

# %%
np.random.randint(1,500,100)
# Out:
# array([325, 290, 291,   8, 196, 296,  91, 443, 401, 157, 135, 329, 166,
#        139, 270, 220, 314, 181,  10,  61, 245, 291, 223, 393,  32, 311,
#        263, 312, 114, 268, 375, 384, 477, 257, 145, 470,  33, 357, 295,
#        206, 478, 334, 106, 334, 170, 104, 257,  47, 438, 275, 164, 356,
#        321,  90, 200,  65,   8, 107, 384, 410,  76, 293, 419, 425, 350,
#         16,  53,   5, 297, 164,  29, 174, 487, 202, 186, 435, 273, 114,
#          8,  69,  76,  73, 344, 316, 194, 221, 347, 299,  75, 366, 174,
#         39, 353, 160, 164,  18, 234, 140, 187, 455])

# %%
frm=pd.DataFrame({'a':np.random.randn(100),"b":np.random.randint(1,500,100)})
store=pd.HDFStore("mydata.h5")
store["obj1"]=frm
store
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: mydata.h5

# %%
store["obj1"]
# Out:
#            a    b
# 0   1.448138  351
# 1   1.028980  201
# 2  -1.293013  423
# 3  -0.692724    5
# 4   0.841473  284
# ..       ...  ...
# 95 -0.199071  195
# 96 -1.027088  199
# 97 -1.903163  188
# 98 -0.896447  193
# 99  0.608105   30
#
# [100 rows x 2 columns]

# %%
store["obj1_col"]=frm["b"]
store["obj1_col"]
# Out:
# 0     351
# 1     201
# 2     423
# 3       5
# 4     284
#      ...
# 95    195
# 96    199
# 97    188
# 98    193
# 99     30
# Name: b, Length: 100, dtype: int32

# %% [markdown]
# # WEB API(Application Programming Interface)
# #### API gives you the flexibility to connect with any system in terms to getting back someting or sending response

# %%
import requests
url="https://api.github.com/repos/pandas-dev/pandas/issues"
resp=requests.get(url)
resp
# Out:
# <Response [200]>

# %% [markdown]
# #### Note- We get <200> it means we suceesfully get response or if we see <500> or <404> or any other it is an error

# %%
# As in example here
url="https://api.github.com/repos/panda/pandas/issues"
resp=requests.get(url)
resp
# Out:
# <Response [404]>

# %%
type(resp)
# Out:
# requests.models.Response

# %% [markdown]
# ### Readin using JSON

# %%
dta=resp.json()
dta
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42432',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42432/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42432/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42432/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/42432',
#   'id': 939078741,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Njg1MzU0Njcz',
#   'number': 42432,
#   'title': 'Backport PR #42419 on branch 1.3.x (CI: update vm image version for Azure)',
#   'user': {'login': 'meeseeksmachine',
#    'id': 39504233,
#    'node_id': 'MDQ6VXNlcjM5NTA0MjMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39504233?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/meeseeksmachine',
#    'html_url': 'https://github.com/meeseeksmachine',
# ...

# %% [markdown]
# ## this data is not human readable format we can use JSON Viewer online

# %%
# Now suppose we want title from 0th record which we see via json viewer(structure and format of data)
dta[0]["title"]
# Out:
# 'BUG: pd.cut with duplicate index Series lowest included'

# %%
# ti get ID
dta[0]["user"]["id"]
# Out:
# 6472290

# %%
# to extract all ID from dataset
l=[]
for i in range(len(dta)):
    l.append(dta[i]["user"]["id"])
l
# Out:
# [6472290,
#  11986836,
#  1706695,
#  13159005,
#  63334933,
#  7614606,
#  25299948,
#  37011898,
#  1911521,
#  26389732,
#  6472290,
#  8284922,
#  34067903,
#  8284922,
#  51399800,
#  387511,
#  387511,
#  42851186,
#  6472290,
#  4510984,
#  8238804,
#  8078968,
#  8238804,
#  63334933,
#  6618166,
#  42706631,
#  42706631,
#  47963215,
#  33491632,
#  86786852]

# %% [markdown]
# ### Presenting some columns into DataFrame

# %%
issues=pd.DataFrame(dta,columns=["number","id","labels","node_id"])
issues.head()
# Out:
#    number         id                                             labels  \
# 0   42432  939078741  [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...
# 1   42431  939074233  [{'id': 1954720290, 'node_id': 'MDU6TGFiZWwxOT...
# 2   42430  939072047  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...
# 3   42429  939038433  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...
# 4   42428  939033494  [{'id': 1280988427, 'node_id': 'MDU6TGFiZWwxMj...
#
#                             node_id
# 0  MDExOlB1bGxSZXF1ZXN0Njg1MzU0Njcz
# 1          MDU6SXNzdWU5MzkwNzQyMzM=
# 2          MDU6SXNzdWU5MzkwNzIwNDc=
# 3          MDU6SXNzdWU5MzkwMzg0MzM=
# 4  MDExOlB1bGxSZXF1ZXN0Njg1MzE2MTIw

# %% [markdown]
# ### Q- Separated id from lables and store them in a List

# %%
issues["labels"][0]
# Out:
# [{'id': 48070600,
#   'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#   'name': 'CI',
#   'color': 'a2bca7',
#   'default': False,
#   'description': 'Related to Continuous Integration'}]

# %%
l=[]
for j in range(len(issues)):
    for i in issues["labels"][j]:
        l.append(i["id"])
        
l
# Out:
# [48070600,
#  1954720290,
#  34444536,
#  76811,
#  1954720290,
#  76811,
#  1954720290,
#  1280988427,
#  134699,
#  76812,
#  76811,
#  1954720290,
#  76811,
#  1954720290,
#  1280988427,
#  134699,
#  1954720290,
#  134699,
#  233160,
#  1954720290,
#  76811,
#  1954720290,
#  57296398,
#  134699,
#  233160,
#  76811,
#  1954720290,
#  76811,
#  1954720290,
#  31404521,
#  32815646,
#  233160,
#  32815646,
#  233160,
#  32815646,
#  211840,
#  76811,
#  2365504893,
#  47229171,
#  32815646,
#  34444536,
#  134699,
#  134699,
#  1954720290,
#  697792067,
#  32815646,
#  76811,
#  1954720290,
#  134699,
#  1357732944,
#  717120670,
#  1280988427]

# %% [markdown]
# #### Unravel LAbel into all the key values present in it as columns

# %%
tst=pd.DataFrame(issues["labels"])
tst.head()
# Out:
#                                               labels
# 0  [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...
# 1  [{'id': 1954720290, 'node_id': 'MDU6TGFiZWwxOT...
# 2  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...
# 3  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...
# 4  [{'id': 1280988427, 'node_id': 'MDU6TGFiZWwxMj...

# %%
mdf=pd.DataFrame()
for i in range(len(issues)):
    df=pd.DataFrame(issues["labels"][i])
    mdf=mdf.append(df,ignore_index=True)
mdf
# Out:
#             id                   node_id  \
# 0     48070600  MDU6TGFiZWw0ODA3MDYwMA==
# 1   1954720290  MDU6TGFiZWwxOTU0NzIwMjkw
# 2     34444536  MDU6TGFiZWwzNDQ0NDUzNg==
# 3        76811      MDU6TGFiZWw3NjgxMQ==
# 4   1954720290  MDU6TGFiZWwxOTU0NzIwMjkw
# 5        76811      MDU6TGFiZWw3NjgxMQ==
# 6   1954720290  MDU6TGFiZWwxOTU0NzIwMjkw
# 7   1280988427  MDU6TGFiZWwxMjgwOTg4NDI3
# 8       134699      MDU6TGFiZWwxMzQ2OTk=
# 9        76812      MDU6TGFiZWw3NjgxMg==
# 10       76811      MDU6TGFiZWw3NjgxMQ==
# 11  1954720290  MDU6TGFiZWwxOTU0NzIwMjkw
# 12       76811      MDU6TGFiZWw3NjgxMQ==
# 13  1954720290  MDU6TGFiZWwxOTU0NzIwMjkw
# 14  1280988427  MDU6TGFiZWwxMjgwOTg4NDI3
# 15      134699      MDU6TGFiZWwxMzQ2OTk=
# 16  1954720290  MDU6TGFiZWwxOTU0NzIwMjkw
# 17      134699      MDU6TGFiZWwxMzQ2OTk=
# 18      233160      MDU6TGFiZWwyMzMxNjA=
# 19  1954720290  MDU6TGFiZWwxOTU0NzIwMjkw
# 20       76811      MDU6TGFiZWw3NjgxMQ==
# 21  1954720290  MDU6TGFiZWwxOTU0NzIwMjkw
# ...
