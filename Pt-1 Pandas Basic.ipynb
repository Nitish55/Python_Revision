# %%
import pandas as pd

# %% [markdown]
# ## Initially getting Error while reding xlsx file so used
# ### pip install xlrd==1.2.0 to solve this

# %% [markdown]
# ###### Reading File

# %%
# added encoding='cp1252' to solve unicode 'utf-8' Error'
fle=pd.read_csv("covid.csv",encoding='cp1252')
fle.head()
# Out:
#                                         description  \
# 0  Business status Alert Level 4: Fully operational
# 1  Business status Alert Level 4: Fully operational
# 2  Business status Alert Level 4: Fully operational
# 3  Business status Alert Level 4: Fully operational
# 4  Business status Alert Level 4: Fully operational
#
#                            industry  level             size line_code  value
# 0                             total      0   6–19 employees  C0301.01   6054
# 1                             total      0  20–49 employees  C0301.01   1650
# 2                             total      0  50–99 employees  C0301.01    735
# 3                             total      0   100+ employees  C0301.01    711
# 4  Agriculture, forestry, & fishing      1            total  C0301.01   2175

# %%
fle.tail(2)
# Out:
#                                              description        industry  \
# 10056  Reasons why you expect COVID-19 pandemic to ch...  Other services
# 10057  Reasons why you expect COVID-19 pandemic to ch...           total
#
#        level   size line_code  value
# 10056      1  total     C2309     12
# 10057      0  total     C2309    231

# %% [markdown]
# #### Reading Tab separeated data atsv file

# %%
f=pd.read_table("Tab_separated.tsv")
f
# Out:
#     Name  Age     Sex  Salary
# 0  Rahul   32    Male    3000
# 1  Pooja   23  Female    4000
# 2  Swati   30  Female    5000
# 3    Jin   32    Male       0
# 4   Paul   33    Male    4000

# %% [markdown]
# ### In case we want to ignore the header, move header to rows

# %%
hid_head=pd.read_table("Tab_separated.tsv",header=None)
hid_head
# Out:
#        0    1       2       3
# 0   Name  Age     Sex  Salary
# 1  Rahul   32    Male    3000
# 2  Pooja   23  Female    4000
# 3  Swati   30  Female    5000
# 4    Jin   32    Male    0000
# 5   Paul   33    Male    4000

# %% [markdown]
# #### Ignore the header, strt reading from row num 1----. using skiprows

# %%
hd=pd.read_table("Tab_separated.tsv",header=None ,skiprows=[0])
hd
# Out:
#        0   1       2     3
# 0  Rahul  32    Male  3000
# 1  Pooja  23  Female  4000
# 2  Swati  30  Female  5000
# 3    Jin  32    Male     0
# 4   Paul  33    Male  4000

# %% [markdown]
# #### Reading text file with sepator

# %%
txt_fle=pd.read_csv("sample.txt",sep="\t")
txt_fle
# Out:
#    EmpID   Name     Role
# 0      1   Soni      H.R
# 1      2  Rahul  Manager
# 2      3  Mohit  Analyst

# %% [markdown]
# ### Providing my own column name

# %%
nw_col=pd.read_csv("sample.txt",sep="\t",header=None,skiprows=[0],names=["Worker_sankhya","Naam","Pdh"])
nw_col
# Out:
#    Worker_sankhya   Naam      Pdh
# 0               1   Soni      H.R
# 1               2  Rahul  Manager
# 2               3  Mohit  Analyst

# %%
ne=pd.read_csv("sample.txt",sep="\t",names=["col1","col2"])
ne
# Out:
#         col1     col2
# EmpID   Name     Role
# 1       Soni      H.R
# 2      Rahul  Manager
# 3      Mohit  Analyst

# %% [markdown]
# #### If we pass more columns name than the value we receive null values also duplicate column name are not allowed

# %%
cols=pd.read_csv("sample.txt",sep="\t",names=["Worker_sankhya","Naam","Pdh","extra_col"],skiprows=[0])
cols
# Out:
#    Worker_sankhya   Naam      Pdh  extra_col
# 0               1   Soni      H.R        NaN
# 1               2  Rahul  Manager        NaN
# 2               3  Mohit  Analyst        NaN

# %% [markdown]
# ### In case we want to change the index rows to any column we use index_col

# %%
nw=pd.read_csv("sample.txt",sep="\t")
nw
# Out:
#    EmpID   Name     Role
# 0      1   Soni      H.R
# 1      2  Rahul  Manager
# 2      3  Mohit  Analyst

# %% [markdown]
# ### in here we use Empid as row index instead of [0,1,2,3]

# %%
idx=pd.read_csv("sample.txt",sep="\t",index_col=["EmpID"])
idx
# Out:
#         Name     Role
# EmpID
# 1       Soni      H.R
# 2      Rahul  Manager
# 3      Mohit  Analyst

# %%
smple=pd.read_csv("Sample_fle.csv")
smple
# Out:
#   Key1 Key2  Value1  Value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10
# 5  two    b      11      12
# 6  two    c      13      14
# 7  two    d      15      16

# %%
smple1=pd.read_csv("Sample_fle.csv",index_col=["Key1","Key2"])
smple1
# Out:
#            Value1  Value2
# Key1 Key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %% [markdown]
# ### We get this result as notice one is common till value1 [7] , now value2 having value 6 belongs to key1--one of key2---c

# %% [markdown]
# # SkipRows more Example

# %%
jm=pd.read_csv("jumbled.txt")
jm
# Out:
#                                                              # hey !
# a                                        b   c   d           message
# #just wanted to make things complex      NaN NaN NaN             NaN
# #Genghis khan is just a human as you are NaN NaN NaN             NaN
# 1                                        2   3   4             hello
# 5                                        6   7   8             World
# 9                                        10  11  12   Om Namah Sivay

# %% [markdown]
# #### As you can see data here is jumbled valid data is present at specific location

# %%
jm=pd.read_csv("jumbled.txt",skiprows=[0])
jm
# Out:
#                                           a     b     c     d         message
# 0       #just wanted to make things complex   NaN   NaN   NaN             NaN
# 1  #Genghis khan is just a human as you are   NaN   NaN   NaN             NaN
# 2                                         1   2.0   3.0   4.0           hello
# 3                                         5   6.0   7.0   8.0           World
# 4                                         9  10.0  11.0  12.0  Om Namah Sivay

# %%
jm=pd.read_csv("jumbled.txt",skiprows=[0,2,3],header=None)
jm
# Out:
#    0   1   2   3               4
# 0  a   b   c   d         message
# 1  1   2   3   4           hello
# 2  5   6   7   8           World
# 3  9  10  11  12  Om Namah Sivay

# %% [markdown]
# ### Identifying Null Values

# %%
fle=pd.read_csv("Null_val.txt",sep=',')
fle
# Out:
#     Name   age     sex  salary
# 0   John  33.0    Male     NaN
# 1    NaN  32.0  Female  3000.0
# 2    NaN   NaN    Male     NaN
# 3  Kumar  22.0    Male  5000.0

# %%
fle.isnull()
# Out:
#     Name    age    sex  salary
# 0  False  False  False    True
# 1   True  False  False   False
# 2   True   True  False    True
# 3  False  False  False   False

# %%
fle.isnull().sum()
# Out:
# Name      2
# age       1
# sex       0
# salary    2
# dtype: int64

# %% [markdown]
# ### Using na_values--> if we want some data elemnt as null we pass it into na_values for eg- In given below example we pass "kumar" into na_values output give it as NaN:-

# %%
nl_val=pd.read_csv("Null_val.txt",na_values="Kumar")
nl_val
# Out:
#    Name   age     sex  salary
# 0  John  33.0    Male     NaN
# 1   NaN  32.0  Female  3000.0
# 2   NaN   NaN    Male     NaN
# 3   NaN  22.0    Male  5000.0

# %% [markdown]
# ### Passing Sheet Name

# %%
import pandas as pd

# %%
s_nme=pd.read_excel(r"Multiple.xlsx")
s_nme.head()
# Out:
#                                         description  \
# 0  Business status Alert Level 4: Fully operational
# 1  Business status Alert Level 4: Fully operational
# 2  Business status Alert Level 4: Fully operational
# 3  Business status Alert Level 4: Fully operational
# 4  Business status Alert Level 4: Fully operational
#
#                            industry  level             size line_code  value
# 0                             total      0   6–19 employees  C0301.01   6054
# 1                             total      0  20–49 employees  C0301.01   1650
# 2                             total      0  50–99 employees  C0301.01    735
# 3                             total      0   100+ employees  C0301.01    711
# 4  Agriculture, forestry, & fishing      1            total  C0301.01   2175

# %% [markdown]
# ## Reading second Sheet
# # Also we cant read all sheets at a time only one sheet at one time

# %%
snd_sheet=pd.read_excel(r"Multiple.xlsx",sheet_name="tendulkar")
snd_sheet.head()
# Out:
#    Unnamed: 0 Runs Mins  BF 4s 6s      SR Pos Dismissal Inns     Opposition  \
# 0           1    0    -   2  0  0       0   5    caught    2     v Pakistan
# 1           2    0    2   2  0  0       0   5    caught    2  v New Zealand
# 2           3   36   51  39  5  0    92.3   6    caught    1  v New Zealand
# 3           4   19   38  35  1  1   54.28   4    bowled    2      v England
# 4           5   31   31  26  3  0  119.23   6    bowled    2      v England
#
#        Ground Start Date
# 0  Gujranwala 1989-12-18
# 1     Dunedin 1990-03-01
# 2  Wellington 1990-03-06
# 3       Leeds 1990-07-18
# 4  Nottingham 1990-07-20

# %%
# changing col_name from unchanged:0 to other
ss=pd.read_excel(r"Multiple.xlsx",sheet_name="tendulkar",header=None,names=["Serial_no"])
ss.head()
# Out:
#                                                                                       Serial_no
# NaN   Runs Mins BF 4s 6s SR    Pos Dismissal Inns Opposition    Ground               Start Date
# 1.0   0    -    2  0  0  0     5   caught    2    v Pakistan    Gujranwala  1989-12-18 00:00:00
# 2.0   0    2    2  0  0  0     5   caught    2    v New Zealand Dunedin     1990-03-01 00:00:00
# 3.0   36   51   39 5  0  92.3  6   caught    1    v New Zealand Wellington  1990-03-06 00:00:00
# 4.0   19   38   35 1  1  54.28 4   bowled    2    v England     Leeds       1990-07-18 00:00:00

# %% [markdown]
# ## If we dont do header=None we got an Error

# %%
ss=pd.read_excel(r"Multiple.xlsx",sheet_name="tendulkar",names=["Serial_no"])
ss.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-4055800a4795> in <module>
# ----> 1 ss=pd.read_excel(r"Multiple.xlsx",sheet_name="tendulkar",names=["Serial_no"])
#       2 ss.head()
#
# E:\Software_install\anaconda\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     332         convert_float=convert_float,
#     333         mangle_dupe_cols=mangle_dupe_cols,
# --> 334         **kwds,
#     335     )
#     336
#
# ...

# %%
#### As we can see we get error if we change one column so we have to pass all columns
ss=pd.read_excel(r"Multiple.xlsx",sheet_name="tendulkar",names=['Serial_no', 'Runs', 'Mins', 'BF', '4s', '6s', 'SR', 'Pos',
       'Dismissal', 'Inns', 'Opposition', 'Ground', 'Start Date'])
ss.head()
# Out:
#    Serial_no Runs Mins  BF 4s 6s      SR Pos Dismissal Inns     Opposition  \
# 0          1    0    -   2  0  0       0   5    caught    2     v Pakistan
# 1          2    0    2   2  0  0       0   5    caught    2  v New Zealand
# 2          3   36   51  39  5  0    92.3   6    caught    1  v New Zealand
# 3          4   19   38  35  1  1   54.28   4    bowled    2      v England
# 4          5   31   31  26  3  0  119.23   6    bowled    2      v England
#
#        Ground Start Date
# 0  Gujranwala 1989-12-18
# 1     Dunedin 1990-03-01
# 2  Wellington 1990-03-06
# 3       Leeds 1990-07-18
# 4  Nottingham 1990-07-20

# %% [markdown]
# ### listing all columns

# %%
ss.columns
# Out:
# Index(['Unnamed: 0', 'Runs', 'Mins', 'BF', '4s', '6s', 'SR', 'Pos',
#        'Dismissal', 'Inns', 'Opposition', 'Ground', 'Start Date'],
#       dtype='object')

# %% [markdown]
# ## Reading data from HTML i.e websites

# %% [markdown]
# ### Limitation
# #### -Only read dataset in tabular format

# %%
kl=pd.read_html("https://www.basketball-reference.com/leaders/orb_top_10.html")

# %%
len(kl)
# Out:
# 1

# %% [markdown]
# ### Data is stored in List format, Coz its possible to have multiple table on a single html website

# %%
type(kl)
# Out:
# list

# %%
kl
# Out:
# [     Season   Lg                 1st                                2nd  \
#  0   2020-21  NBA     C. Capela (297)                    E. Kanter (284)
#  1   2019-20  NBA  H. Whiteside (258)                  A. Drummond (250)
#  2   2018-19  NBA   A. Drummond (423)                     S. Adams (391)
#  3   2017-18  NBA   A. Drummond (399)                     S. Adams (384)
#  4   2016-17  NBA   A. Drummond (345)                    R. Gobert (314)
#  5   2015-16  NBA   A. Drummond (395)  R. Lopez (268), T. Thompson (268)
#  6   2014-15  NBA   A. Drummond (437)                    D. Jordan (397)
#  7   2013-14  NBA   A. Drummond (440)                    D. Jordan (331)
#  8   2012-13  NBA   Z. Randolph (310)                  T. Thompson (306)
#  9   2011-12  NBA    D. Cousins (265)                      J. Noah (242)
#  10  2010-11  NBA       K. Love (330)                  Z. Randolph (326)
#  11  2009-10  NBA   Z. Randolph (330)                    D. Howard (284)
# ...

# %% [markdown]
# ### Saving the data into Dataframwe

# %%
df=kl[0]
df.head()
# Out:
#     Season   Lg                 1st                2nd                   3rd  \
# 0  2020-21  NBA     C. Capela (297)    E. Kanter (284)  J. Valančiūnas (253)
# 1  2019-20  NBA  H. Whiteside (258)  A. Drummond (250)       R. Gobert (230)
# 2  2018-19  NBA   A. Drummond (423)     S. Adams (391)       R. Gobert (309)
# 3  2017-18  NBA   A. Drummond (399)     S. Adams (384)       D. Jordan (329)
# 4  2016-17  NBA   A. Drummond (345)    R. Gobert (314)       D. Jordan (298)
#
#                                4th              5th  \
# 0                  R. Gobert (240)   D. Ayton (228)
# 1                T. Thompson (226)   J. Allen (216)
# 2                  C. Capela (298)   K. Towns (263)
# 3                  E. Kanter (273)  D. Howard (255)
# 4  D. Howard (296), K. Towns (296)              NaN
#
#                                    6th                7th                8th  \
# 0                      J. Poeltl (219)     S. Adams (213)     N. Jokić (205)
# ...

# %% [markdown]
# ### Extracting Columns from a dataframe

# %% [markdown]
# ### If we extract only one column or one row from a Dataframe it is called 'SERIES'

# %%
df["Lg"].head()
# Out:
# 0    NBA
# 1    NBA
# 2    NBA
# 3    NBA
# 4    NBA
# Name: Lg, dtype: object

# %%
# Dataframe is a coolectio of series
type(df["Lg"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### If we pass one columnn in a list as given below it will be a dataFrame

# %%
type(df[["Lg"]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### if we do df["Lg","4th"] we got an Error, in that case we pass elemnt in list if there are more than 1 elements

# %%
df[["Lg","4th"]].head()
# Out:
#     Lg                              4th
# 0  NBA                  R. Gobert (240)
# 1  NBA                T. Thompson (226)
# 2  NBA                  C. Capela (298)
# 3  NBA                  E. Kanter (273)
# 4  NBA  D. Howard (296), K. Towns (296)

# %% [markdown]
# ## Reading Data from GITHUB

# %%
gt=pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv"
              ,sep="\t")
gt
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Checking Data Type of each Column

# %%
gt.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # Assingment

# %% [markdown]
# Q-1-Read dataset on "https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv"

# %%
am=pd.read_csv("https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv"
              ,sep=";")
am.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %% [markdown]
# ## 2 change column name

# %%
am.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
at=pd.read_csv("https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv"
              ,sep=";",names=['umar', 'job', 'marital', 'education', 'default', 'housing', 'loan',
       'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
       'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
       'cons.conf.idx', 'euribor3m', 'nr.employed', 'nuhi'],skiprows=[0])
at.head()
# Out:
#    umar        job  marital    education  default housing loan    contact  \
# 0    56  housemaid  married     basic.4y       no      no   no  telephone
# 1    57   services  married  high.school  unknown      no   no  telephone
# 2    37   services  married  high.school       no     yes   no  telephone
# 3    40     admin.  married     basic.6y       no      no   no  telephone
# 4    56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
import pandas as pd

# %%
at=pd.read_csv("https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv"
              ,sep=";",names=['umar'])
at.head()
# Out:
# E:\Software_install\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (0,10,11,12,13,15,16,17,18,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                                                                                                                                                                                 umar
# age job       marital education   default housing loan contact   month day_of_week duration campaign pdays previous poutcome    emp.var.rate cons.price.idx cons.conf.idx euribor3m nr.employed    y
# 56  housemaid married basic.4y    no      no      no   telephone may   mon         261      1        999   0        nonexistent 1.1          93.994         -36.4         4.857     5191          no
# ...

# %%
nw=at.rename(columns={"job":"Kaam"})
nw.head(3)
# Out:
#    umar       Kaam  marital    education  default housing loan    contact  \
# 0    56  housemaid  married     basic.4y       no      no   no  telephone
# 1    57   services  married  high.school  unknown      no   no  telephone
# 2    37   services  married  high.school       no     yes   no  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  nuhi
# 0          93.994          -36.4      4.857       5191.0    no
# 1          93.994          -36.4      4.857       5191.0    no
# 2          93.994          -36.4      4.857       5191.0    no
#
# [3 rows x 21 columns]

# %% [markdown]
# ## Q3-Select one column and print its data type

# %%
at[["umar"]].dtypes
# Out:
# umar    int64
# dtype: object

# %% [markdown]
# ### Q4- Print Data Type

# %%
at.dtypes
# Out:
# umar                int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# nuhi               object
# dtype: object

# %% [markdown]
# ### Q5-Check if any data is null

# %%
at.isnull().sum()
# Out:
# umar              0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# nuhi              0
# dtype: int64

# %% [markdown]
# ## Skip Radom Rows

# %%
gt=pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv"
              ,sep="\t",skiprows=[2,4,5,6,7])
gt.head(8)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            3         1       3
# 2            8         0       3
# 3            9         1       3
# 4           10         1       2
# 5           11         1       3
# 6           12         1       1
# 7           13         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1                             Heikkinen, Miss. Laina  female  26.0      0
# 2                     Palsson, Master. Gosta Leonard    male   2.0      3
# 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 4                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 5                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 6                           Bonnell, Miss. Elizabeth  female  58.0      0
# ...

# %% [markdown]
# # Limiting the display Option

# %%
pd.options.display.max_rows=4

# %%
gt=pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv"
              ,sep="\t",skiprows=[2,4,5,6,7])
gt
# Out:
#      PassengerId  Survived  Pclass                         Name     Sex   Age  \
# 0              1         0       3      Braund, Mr. Owen Harris    male  22.0
# 1              3         1       3       Heikkinen, Miss. Laina  female  26.0
# ..           ...       ...     ...                          ...     ...   ...
# 149          155         0       3        Olsen, Mr. Ole Martin    male   NaN
# 150          156         0       1  Williams, Mr. Charles Duane    male  51.0
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked
# 0        1      0         A/5 21171   7.2500   NaN        S
# 1        0      0  STON/O2. 3101282   7.9250   NaN        S
# ..     ...    ...               ...      ...   ...      ...
# 149      0      0         Fa 265302   7.3125   NaN        S
# 150      0      1          PC 17597  61.3792   NaN        C
#
# [151 rows x 12 columns]
